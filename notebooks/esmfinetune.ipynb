# %% [markdown]
# Bionemo ESM2 fine-tuning https://docs.nvidia.com/bionemo-framework/2.3/user-guide/examples/bionemo-esm2/finetune/
#
# docker login nvcr.io
#
# username = $oauthtoken
#
# pw = api key
#
# docker pull nvcr.io/nvidia/clara/bionemo-framework:2.3
#
#
# docker run \
#   --rm -it \
#   --gpus all \
#   --network host \
#   --shm-size=4g \
#   -e WANDB_API_KEY \
#   -e NGC_CLI_API_KEY \
#   -e NGC_CLI_ORG \
#   -e NGC_CLI_TEAM \
#   -e NGC_CLI_FORMAT_TYPE \
#   -v $LOCAL_DATA_PATH:$DOCKER_DATA_PATH \
#   -v $LOCAL_MODELS_PATH:$DOCKER_MODELS_PATH \
#   -v $LOCAL_RESULTS_PATH:$DOCKER_RESULTS_PATH \
#   nvcr.io/nvidia/clara/bionemo-framework:2.3 \
#   /bin/bash
